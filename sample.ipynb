# %%
from jupyturtle import make_turtle, forward, right, left
from wcwidth import width

"""
def rectangle(width: int= 80,height : int = 40):
    make_turtle()
    for i in range(2):
        forward(width)
        left(90)
        forward(height)
        left(90)

rectangle(80,60)

"""

"""
def rhombus(width: int = 50,angle : int = 60):
    make_turtle()
    for i in range(2):
        forward(width)
        left(angle)
        forward(width)
        left(180-angle)

rhombus(50,40)
"""
def parallelogram(width: int = 50,height : int = 40,angle : int = 60):
    make_turtle()
    for i in range(2):
        forward(width)
        left(angle)
        forward(height)
        left(180-angle)

def rhombus(width: int = 50,angle : int = 60):
    height = width
    parallelogram(width,height,angle)

def rectangle(width: int = 80,height : int = 40):
    angle = 90
    parallelogram(width,height,angle)

def square(l : int = 50):
    length = l
    width = l
    angle = 90
    parallelogram(length,width,angle)

square(60)
